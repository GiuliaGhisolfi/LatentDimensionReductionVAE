# %%
from src.autoencoders.vae import VariationalAutoEncoder
from src.utils.utils import get_training_and_validation_sets, get_test_set, save_latent_vectors
# Out:
# c:\Users\giuli\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# c:\Users\giuli\anaconda3\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
X_train, Y_train, cX_train = get_training_and_validation_sets(scenario='obj')
X_val, Y_val, cX_val = get_test_set(scenario='obj')

# %%
X_train.shape, X_val.shape
# Out:
# ((5431, 3, 64, 64), (2196, 3, 64, 64))

# %%
vae = VariationalAutoEncoder(
        input_dim=[3, 64, 64],
        latent_dim=1280,
        n_filters=[4, 4],
        kernel_size=[32, 16],
        stride=[2, 2],
        padding=['same', 'same'],
        hidden_dims=[2560],
        activation='relu',
        learning_rate=0.001, # alzare ?
        dropout=0.4,
        alpha=0.3, # LeakyReLU alpha
        loss_function='mse',
        patience=10,
        metrics=['mae'],
        save_model=True,
        save_path='vae_rgb_1280_obj',
)

# %%
vae.train(X_train, X_val, epochs=300, batch_size=128)
# Out:
# Epoch 1/300
# 43/43 [==============================] - 149s 3s/step - loss: 0.1137 - mae: 0.3213 - val_loss: 0.0971 - val_mae: 0.2979
# Epoch 2/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0832 - mae: 0.2759 - val_loss: 0.0692 - val_mae: 0.2522
# Epoch 3/300
# 43/43 [==============================] - 128s 3s/step - loss: 0.0584 - mae: 0.2310 - val_loss: 0.0481 - val_mae: 0.2090
# Epoch 4/300
# 43/43 [==============================] - 136s 3s/step - loss: 0.0405 - mae: 0.1903 - val_loss: 0.0334 - val_mae: 0.1712
# Epoch 5/300
# 43/43 [==============================] - 115s 3s/step - loss: 0.0285 - mae: 0.1556 - val_loss: 0.0241 - val_mae: 0.1401
# Epoch 6/300
# 43/43 [==============================] - 111s 3s/step - loss: 0.0211 - mae: 0.1276 - val_loss: 0.0184 - val_mae: 0.1153
# Epoch 7/300
# 43/43 [==============================] - 113s 3s/step - loss: 0.0166 - mae: 0.1060 - val_loss: 0.0150 - val_mae: 0.0969
# Epoch 8/300
# 43/43 [==============================] - 112s 3s/step - loss: 0.0140 - mae: 0.0899 - val_loss: 0.0130 - val_mae: 0.0831
# Epoch 9/300
# 43/43 [==============================] - 112s 3s/step - loss: 0.0123 - mae: 0.0777 - val_loss: 0.0116 - val_mae: 0.0723
# Epoch 10/300
# 43/43 [==============================] - 115s 3s/step - loss: 0.0111 - mae: 0.0685 - val_loss: 0.0108 - val_mae: 0.0654
# Epoch 11/300
# 43/43 [==============================] - 112s 3s/step - loss: 0.0103 - mae: 0.0622 - val_loss: 0.0100 - val_mae: 0.0598
# Epoch 12/300
# 43/43 [==============================] - 118s 3s/step - loss: 0.0097 - mae: 0.0581 - val_loss: 0.0094 - val_mae: 0.0565
# Epoch 13/300
# 43/43 [==============================] - 117s 3s/step - loss: 0.0090 - mae: 0.0553 - val_loss: 0.0087 - val_mae: 0.0543
# Epoch 14/300
# 43/43 [==============================] - 114s 3s/step - loss: 0.0084 - mae: 0.0531 - val_loss: 0.0082 - val_mae: 0.0519
# Epoch 15/300
# 43/43 [==============================] - 120s 3s/step - loss: 0.
300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0020 - mae: 0.0230 - val_loss: 0.0019 - val_mae: 0.0225
# Epoch 80/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0020 - mae: 0.0230 - val_loss: 0.0019 - val_mae: 0.0223
# Epoch 81/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0020 - mae: 0.0229 - val_loss: 0.0019 - val_mae: 0.0225
# Epoch 82/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0020 - mae: 0.0228 - val_loss: 0.0019 - val_mae: 0.0223
# Epoch 83/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0019 - mae: 0.0227 - val_loss: 0.0018 - val_mae: 0.0221
# Epoch 84/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0019 - mae: 0.0226 - val_loss: 0.0018 - val_mae: 0.0220
# Epoch 85/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0019 - mae: 0.0226 - val_loss: 0.0018 - val_mae: 0.0220
# Epoch 86/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0019 - mae: 0.0224 - val_loss: 0.0018 - val_mae: 0.0219
# Epoch 87/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0019 - mae: 0.0224 - val_loss: 0.0018 - val_mae: 0.0219
# Epoch 88/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0019 - mae: 0.0223 - val_loss: 0.0018 - val_mae: 0.0218
# Epoch 89/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0019 - mae: 0.0223 - val_loss: 0.0018 - val_mae: 0.0217
# Epoch 90/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0019 - mae: 0.0221 - val_loss: 0.0018 - val_mae: 0.0214
# Epoch 91/300
# 43/43 [==============================] - 120s 3s/step - loss: 0.0019 - mae: 0.0221 - val_loss: 0.0018 - val_mae: 0.0216
# Epoch 92/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0019 - mae: 0.0221 - val_loss: 0.0018 - val_mae: 0.0212
# Epoch 93/300
# 43/43 [==============================] - 120s 3s/step - loss: 0.0019 - mae: 0.0220 - val_loss: 0.0018 - val_mae: 0.0213
# Epoch 94/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0018 - mae: 0.0219 - val_loss: 0.0017 - val_mae: 0.0213
# Epoch 95/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0018 - mae: 0.0218 - val_loss: 0.0017 - val_mae: 0.0216
# Epoch 96/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0018 - mae: 0.0219 - val_loss: 0.0017 - val_mae: 0.0212
# Epoch 97/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0018 - mae: 0.0217 - val_loss: 0.0017 - val_mae: 0.0212
# Epoch 98/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0018 - mae: 0.0217 - val_loss: 0.0017 - val_mae: 0.0211
# Epoch 99/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0018 - mae: 0.0216 - val_loss: 0.0017 - val_mae: 0.0212
# Epoch 100/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0018 - mae: 0.0217 - val_loss: 0.0017 - val_mae: 0.0210
# Epoch 101/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0018 - mae: 0.0216 - val_loss: 0.0017 - val_mae: 0.0209
# Epoch 102/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0018 - mae: 0.0214 - val_loss: 0.0017 - val_mae: 0.0207
# Epoch 103/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0018 - mae: 0.0213 - val_loss: 0.0017 - val_mae: 0.0206
# Epoch 104/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0018 - mae: 0.0213 - val_loss: 0.0017 - val_mae: 0.0208
# Epoch 105/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0018 - mae: 0.0212 - val_loss: 0.0017 - val_mae: 0.0206
# Epoch 106/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0018 - mae: 0.0211 - val_loss: 0.0017 - val_mae: 0.0204
# Epoch 107/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0018 - mae: 0.0211 - val_loss: 0.0017 - val_mae: 0.0210
# Epoch 108/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0018 - mae: 0.0211 - val_loss: 0.0017 - val_mae: 0.0206
# Epoch 109/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0017 - mae: 0.0210 - val_loss: 0.0016 - val_mae: 0.0202
# Epoch 110/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0017 - mae: 0.0208 - val_loss: 0.0016 - val_mae: 0.0202
# Epoch 111/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0017 - mae: 0.0208 - val_loss: 0.0016 - val_mae: 0.0201
# Epoch 112/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0017 - mae: 0.0208 - val_loss: 0.0016 - val_mae: 0.0201
# Epoch 113/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0017 - mae: 0.0209 - val_loss: 0.0016 - val_mae: 0.0201
# Epoch 114/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.
300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0015 - mae: 0.0188 - val_loss: 0.0014 - val_mae: 0.0183
# Epoch 159/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0015 - mae: 0.0189 - val_loss: 0.0014 - val_mae: 0.0183
# Epoch 160/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0015 - mae: 0.0188 - val_loss: 0.0014 - val_mae: 0.0181
# Epoch 161/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0015 - mae: 0.0187 - val_loss: 0.0014 - val_mae: 0.0180
# Epoch 162/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0015 - mae: 0.0187 - val_loss: 0.0014 - val_mae: 0.0182
# Epoch 163/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0015 - mae: 0.0188 - val_loss: 0.0014 - val_mae: 0.0179
# Epoch 164/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0015 - mae: 0.0187 - val_loss: 0.0014 - val_mae: 0.0181
# Epoch 165/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0015 - mae: 0.0187 - val_loss: 0.0014 - val_mae: 0.0179
# Epoch 166/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0015 - mae: 0.0186 - val_loss: 0.0014 - val_mae: 0.0183
# Epoch 167/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0015 - mae: 0.0187 - val_loss: 0.0014 - val_mae: 0.0179
# Epoch 168/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0015 - mae: 0.0186 - val_loss: 0.0014 - val_mae: 0.0178
# Epoch 169/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0015 - mae: 0.0185 - val_loss: 0.0014 - val_mae: 0.0178
# Epoch 170/300
# 43/43 [==============================] - 124s 3s/step - loss: 0.0015 - mae: 0.0185 - val_loss: 0.0014 - val_mae: 0.0178
# Epoch 171/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0015 - mae: 0.0184 - val_loss: 0.0014 - val_mae: 0.0179
# Epoch 172/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0015 - mae: 0.0186 - val_loss: 0.0014 - val_mae: 0.0179
# Epoch 173/300
# 43/43 [==============================] - 124s 3s/step - loss: 0.0015 - mae: 0.0185 - val_loss: 0.0014 - val_mae: 0.0177
# Epoch 174/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0015 - mae: 0.0184 - val_loss: 0.0014 - val_mae: 0.0178
# Epoch 175/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0015 - mae: 0.0183 - val_loss: 0.0013 - val_mae: 0.0176
# Epoch 176/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0015 - mae: 0.0183 - val_loss: 0.0014 - val_mae: 0.0177
# Epoch 177/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0015 - mae: 0.0183 - val_loss: 0.0014 - val_mae: 0.0177
# Epoch 178/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0014 - mae: 0.0183 - val_loss: 0.0013 - val_mae: 0.0176
# Epoch 179/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0015 - mae: 0.0183 - val_loss: 0.0014 - val_mae: 0.0177
# Epoch 180/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0015 - mae: 0.0183 - val_loss: 0.0013 - val_mae: 0.0175
# Epoch 181/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0182 - val_loss: 0.0013 - val_mae: 0.0174
# Epoch 182/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0181 - val_loss: 0.0013 - val_mae: 0.0175
# Epoch 183/300
# 43/43 [==============================] - 124s 3s/step - loss: 0.0014 - mae: 0.0181 - val_loss: 0.0013 - val_mae: 0.0174
# Epoch 184/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0181 - val_loss: 0.0013 - val_mae: 0.0173
# Epoch 185/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0181 - val_loss: 0.0013 - val_mae: 0.0174
# Epoch 186/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0181 - val_loss: 0.0013 - val_mae: 0.0173
# Epoch 187/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0180 - val_loss: 0.0013 - val_mae: 0.0173
# Epoch 188/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0180 - val_loss: 0.0013 - val_mae: 0.0172
# Epoch 189/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0180 - val_loss: 0.0013 - val_mae: 0.0172
# Epoch 190/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0180 - val_loss: 0.0013 - val_mae: 0.0175
# Epoch 191/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0180 - val_loss: 0.0013 - val_mae: 0.0172
# Epoch 192/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0179 - val_loss: 0.0013 - val_mae: 0.0174
# Epoch 193/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0180 - val_loss: 0.0013 - val_mae: 0.0173
# Epoch 194/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0179 - val_loss: 0.0013 - val_mae: 0.0171
# Epoch 195/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0178 - val_loss: 0.0013 - val_mae: 0.0173
# Epoch 196/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0178 - val_loss: 0.0013 - val_mae: 0.0172
# Epoch 197/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0178 - val_loss: 0.0013 - val_mae: 0.0171
# Epoch 198/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0178 - val_loss: 0.0013 - val_mae: 0.0171
# Epoch 199/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0179 - val_loss: 0.0013 - val_mae: 0.0172
# Epoch 200/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0014 - mae: 0.0178 - val_loss: 0.0013 - val_mae: 0.0172
# Epoch 201/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0178 - val_loss: 0.0013 - val_mae: 0.0171
# Epoch 202/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0177 - val_loss: 0.0013 - val_mae: 0.0170
# Epoch 203/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0177 - val_loss: 0.0013 - val_mae: 0.0171
# Epoch 204/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0177 - val_loss: 0.0013 - val_mae: 0.0169
# Epoch 205/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0176 - val_loss: 0.0013 - val_mae: 0.0169
# Epoch 206/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0177 - val_loss: 0.0013 - val_mae: 0.0170
# Epoch 207/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0177 - val_loss: 0.0013 - val_mae: 0.0170
# Epoch 208/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0176 - val_loss: 0.0013 - val_mae: 0.0168
# Epoch 209/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0014 - mae: 0.0176 - val_loss: 0.0013 - val_mae: 0.0169
# Epoch 210/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0168
# Epoch 211/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0168
# Epoch 212/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0169
# Epoch 213/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0168
# Epoch 214/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0014 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0171
# Epoch 215/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0014 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0168
# Epoch 216/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0174 - val_loss: 0.0013 - val_mae: 0.0167
# Epoch 217/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0014 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0168
# Epoch 218/300
# 43/43 [==============================] - 124s 3s/step - loss: 0.0014 - mae: 0.0174 - val_loss: 0.0013 - val_mae: 0.0167
# Epoch 219/300
# 43/43 [==============================] - 124s 3s/step - loss: 0.0014 - mae: 0.0174 - val_loss: 0.0013 - val_mae: 0.0168
# Epoch 220/300
# 43/43 [==============================] - 124s 3s/step - loss: 0.0014 - mae: 0.0174 - val_loss: 0.0013 - val_mae: 0.0167
# Epoch 221/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0013 - mae: 0.0173 - val_loss: 0.0013 - val_mae: 0.0167
# Epoch 222/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0014 - mae: 0.0174 - val_loss: 0.0013 - val_mae: 0.0166
# Epoch 223/300
# 43/43 [==============================] - 126s 3s/step - loss: 0.0013 - mae: 0.0174 - val_loss: 0.0013 - val_mae: 0.0167
# Epoch 224/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0013 - mae: 0.0173 - val_loss: 0.0013 - val_mae: 0.0166
# Epoch 225/300
# 43/43 [==============================] - 124s 3s/step - loss: 0.0013 - mae: 0.0173 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 226/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0013 - mae: 0.0173 - val_loss: 0.0012 - val_mae: 0.0166
# Epoch 227/300
# 43/43 [==============================] - 124s 3s/step - loss: 0.0013 - mae: 0.0173 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 228/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0013 - mae: 0.0172 - val_loss: 0.0012 - val_mae: 0.0166
# Epoch 229/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0172 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 230/300
# 43/43 [==============================] - 124s 3s/step - loss: 0.0013 - mae: 0.0172 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 231/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0172 - val_loss: 0.0012 - val_mae: 0.0166
# Epoch 232/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0013 - mae: 0.0173 - val_loss: 0.0012 - val_mae: 0.0166
# Epoch 233/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0013 - mae: 0.0172 - val_loss: 0.0012 - val_mae: 0.0166
# Epoch 234/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0172 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 235/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0013 - mae: 0.0171 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 236/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0171 - val_loss: 0.0012 - val_mae: 0.0164
# Epoch 237/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0171 - val_loss: 0.0012 - val_mae: 0.0164
# Epoch 238/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0171 - val_loss: 0.0012 - val_mae: 0.0164
# Epoch 239/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0171 - val_loss: 0.0012 - val_mae: 0.0164
# Epoch 240/300
# 43/43 [==============================] - 123s 3s/step - loss: 0.0013 - mae: 0.0171 - val_loss: 0.0012 - val_mae: 0.0164
# Epoch 241/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0013 - mae: 0.0171 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 242/300
# 43/43 [==============================] - 108s 3s/step - loss: 0.0013 - mae: 0.0171 - val_loss: 0.0012 - val_mae: 0.0164
# Epoch 243/300
# 43/43 [==============================] - 119s 3s/step - loss: 0.0013 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0163
# Epoch 244/300
# 43/43 [==============================] - 109s 3s/step - loss: 0.0013 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0163
# Epoch 245/300
# 43/43 [==============================] - 119s 3s/step - loss: 0.0013 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0163
# Epoch 246/300
# 43/43 [==============================] - 118s 3s/step - loss: 0.0013 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0164
# Epoch 247/300
# 43/43 [==============================] - 117s 3s/step - loss: 0.0013 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0163
# Epoch 248/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0162
# Epoch 249/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0013 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0162
# Epoch 250/300
# 43/43 [==============================] - 118s 3s/step - loss: 0.0013 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0162
# Epoch 251/300
# 43/43 [==============================] - 124s 3s/step - loss: 0.0013 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0162
# Epoch 252/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0162
# Epoch 253/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0162
# Epoch 254/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0161
# Epoch 255/300
# 43/43 [==============================] - 124s 3s/step - loss: 0.0013 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0163
# Epoch 256/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0162
# Epoch 257/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0161
# Epoch 258/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0161
# Epoch 259/300
# 43/43 [==============================] - 121s 3s/step - loss: 0.0013 - mae: 0.0168 - val_loss: 0.0012 - val_mae: 0.0160
# Epoch 260/300
# 43/43 [==============================] - 122s 3s/step - loss: 0.0013 - mae: 0.0168 - val_loss: 0.0012 - val_mae: 0.0160
# Epoch 261/300
# 43/43 [==============================] - 162s 4s/step - loss: 0.0013 - mae: 0.0168 - val_loss: 0.0012 - val_mae: 0.0161
# Epoch 262/300
# 43/43 [==============================] - 128s 3s/step - loss: 0.0013 - mae: 0.0168 - val_loss: 0.0012 - val_mae: 0.0162
# Epoch 263/300
#  5/43 [==>...........................] - ETA: 1:43 - loss: 0.0013 - mae: 0.0169
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 vae.train(X_train, X_val, epochs=300, batch_size=128)
#
# File c:\Documenti\VS_Code\uni\ROBOTICS\LatentDimensionReductionVAE\src\autoencoders\ae.py:243, in AutoEncoder.train(self, X_train, X_val, epochs, batch_size)
#     235 self._compile()
#     237 early_stopping = tf.keras.callbacks.EarlyStopping(
#     238     monitor='val_loss',
#     239     patience=self.patience,
#     240     restore_best_weights=True
#     241 )
# --> 243 self.ae.fit(
#     244     x=X_train,
#     245     y=X_train,
#     246     epochs=epochs,
#     247     batch_size=batch_size,
#     248     validation_data=(X_val, X_val),
#     249     shuffle=True,
#     250     callbacks=[early_stopping],
#     251 )
#     253 if self.save_model:
#     254     self.save()
#
# File c:\Users\giuli\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\giuli\anaconda3\lib\site-packages\keras\engine\training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File c:\Users\giuli\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\giuli\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\giuli\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File c:\Users\giuli\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\giuli\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\giuli\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File c:\Users\giuli\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
vae.visualize_loss()

# %%
for i in range(10):
    vae.visualize_recostruction(X_train[36+i*47])

# %%
X_train_z = vae.compute_latent_vector(X_train)
X_val_z = vae.compute_latent_vector(X_val)
#X_test_z = vae.compute_latent_vector(X_test)
# Out:
# 170/170 [==============================] - 13s 73ms/step
# 69/69 [==============================] - 5s 70ms/step

# %%
save_latent_vectors(X_train_z, None, 'predictions/z_vae_rgb_train_obj.pkl')
save_latent_vectors(X_val_z, None, 'predictions/z_vae_rgb_val_obj.pkl')
#save_latent_vectors(X_test_z, None, 'predictions/z_vae_rgb_test_obj.pkl')

# %%
Y_train_z = vae.compute_latent_vector(Y_train)
Y_val_z = vae.compute_latent_vector(Y_val)
#Y_test_z = vae.compute_latent_vector(Y_test)

save_latent_vectors(Y_train_z, None, 'predictions/zY_vae_rgb_train_obj.pkl')
save_latent_vectors(Y_val_z, None, 'predictions/zY_vae_rgb_val_obj.pkl')
#save_latent_vectors(Y_test_z, None, 'predictions/zY_vae_rgb_test_obj.pkl')
# Out:
# 170/170 [==============================] - 17s 100ms/step
# 69/69 [==============================] - 6s 88ms/step

# %%
# save traning data
import pickle

with open('predictions/dataset_obj.pkl', 'wb') as f:
    pickle.dump((X_train, Y_train, cX_train, X_val, Y_val, cX_val), f)

# %%
# save history in a file
import pickle

with open('predictions/history_rgb_scale_obj.pkl', 'wb') as file_pi:
    pickle.dump(vae.ae.history, file_pi)

# %%
vae.save()
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: saved_models/vae_rgb_1280_obj\assets
# INFO:tensorflow:Assets written to: saved_models/vae_rgb_1280_obj\assets

# %%
from tensorflow.keras.models import save_model

save_model(vae.encoder, 'models/encoder_rgb_obj.h5')
save_model(vae.decoder, 'models/decoder_rgb_obj.h5')
save_model(vae.ae, 'models/ae_rgb_obj.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
